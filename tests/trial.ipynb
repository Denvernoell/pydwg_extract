# %%
import sys
sys.path.append("..")
from autocad.dwg_creator import DWGCreator
creator = DWGCreator()

# Create a circle
creator.create_circle(center=(2, 2), radius=1)

# Create a line
creator.create_line(start_point=(0, 0), end_point=(1, 1))

# Create a chair
creator.create_chair(insertion_point=(4, 0))

# Save the DWG file
creator.save_dwg("output.dwg")
# Out:
# 2024-07-31 11:56:30,671:INFO dwg_creator.py 28: Creating chair
# 2024-07-31 11:56:30,684:INFO dwg_creator.py 38: dwg file saved to output.dwg

# %%
import autocad.extractor as extractor
from pathlib import Path
dwg_shp_path = Path(r"\\ppeng.com\pzdata\clients\Arvin-Edison WSD-1215\121523003-Frick Unit Pipeline\300 CAD\320 References\Sites_Ref\Shapefiles\REF-PROP-SITE-FOR-SHAPEFILES.dwg")
dwg_shp_path = Path(r"\\ppeng.com\pzdata\clients\Arvin-Edison WSD-1215\121523003-Frick Unit Pipeline\300 CAD\320 References\Sites_Ref\REF-PROP-SITE.dwg")
extractor.extract_parameters(
	# str(dwg_shp_path)
	"output.dwg"
)
# Out:
# 2024-07-31 11:58:46,930:INFO extractor.py 28: ['_2nd_loading_stage', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_acad_compatible', '_acad_incompatibility_reason', '_create_appid_if_not_exist', '_create_appids', '_create_ezdxf_metadata', '_create_required_appids', '_create_required_block_records', '_create_required_dimstyles', '_create_required_layers', '_create_required_linetypes', '_create_required_styles', '_create_required_table_entries', '_create_required_vports', '_dimension_renderer', '_dxfversion', '_execute_post_init_commands', '_finalize_setup', '_load', '_load_section_dict', '_loaded_dxfversion', '_set_required_layer_attributes', '_setup', '_setup_metadata', '_update_ezdxf_metadata', '_update_header_vars', '_update_metadata', '_validate_dxf_version', 'acad_incompatibility_reasons', 'acad_release', 'acdsdata', 'acquire_arrow', 'active_layout', 'add_acad_incompatibility_message', 'add_image_def', 'add_underlay_def', 'add_xref_def', 'appids', 'audit', 'block_records', 'blocks', 'chain_layouts_and_blocks', 'classes', 'commit_pending_changes', 'create_all_arrow_blocks', 'delete_layout', 'dimension_renderer', 'dimstyles', 'dxfversion', 'encode', 'encode_base64', 'encoding', 'entities', 'entitydb', 'export_sections', 'ezdxf_metadata', 'filename', 'from_tags', 'get_abs_filepath', 'groupby', 'groups', 'header', 'is_acad_compatible', 'is_loading', 'layers', 'layout', 'layout_names', 'layout_names_in_taborder', 'layouts', 'layouts_and_blocks', 'linetypes', 'load', 'loaded_dxfversion', 'materials', 'messenger', 'mleader_styles', 'mline_styles', 'modelspace', 'new', 'new_layout', 'objects', 'output_encoding', 'page_setup', 'paperspace', 'plotstyles', 'query', 'read', 'reset_fingerprint_guid', 'reset_version_guid', 'rootdict', 'save', 'saveas', 'set_modelspace_vport', 'set_raster_variables', 'set_wipeout_variables', 'stored_sections', 'styles', 'tables', 'ucs', 'units', 'update_all', 'update_extents', 'update_limits', 'validate', 'viewports', 'views', 'write']
# 2024-07-31 11:58:46,932:INFO extractor.py 37: Layer: 0, linetype : Continuous, lineweight: -3,
# 2024-07-31 11:58:46,933:INFO extractor.py 38: material_handle: 21, name: 0, owner : 1,
# 2024-07-31 11:58:46,934:INFO extractor.py 39: plot: 1, plotstyle_handle: 13,
# 2024-07-31 11:58:46,935:INFO extractor.py 37: Layer: Defpoints, linetype : Continuous, lineweight: -3,
# 2024-07-31 11:58:46,936:INFO extractor.py 38: material_handle: 21, name: Defpoints, owner : 1,
# 2024-07-31 11:58:46,936:INFO extractor.py 39: plot: 0, plotstyle_handle: 13,
# 2024-07-31 11:58:46,938:INFO extractor.py 50: Entity Type: CIRCLE | Layer: 0 | Color: 256
# 2024-07-31 11:58:46,939:INFO extractor.py 50: Entity Type: LINE | Layer: 0 | Color: 256
# 2024-07-31 11:58:46,940:INFO extractor.py 50: Entity Type: INSERT | Layer: 0 | Color: 256
# 2024-07-31 11:58:46,941:INFO extractor.py 58: Block Name: Chair, dxfattribs : <bound method DXFEntity.dxfattribs of <class 'ezdxf.entities.insert.Insert'> INSERT(#35)>
# 2024-07-31 11:58:46,942:INFO extractor.py 59: dxftype: <bound method DXFEntity.dxftype of <class 'ezdxf.entities.insert.Insert'> INSERT(#35)>
# 2024-07-31 11:58:46,942:ERROR extractor.py 67: Error extracting parameters: Expected end of text, found ':'  (at char 6), (line:1, col:7)
# 2024-07-31 11:58:46,943:INFO extractor.py 70: V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^V^
